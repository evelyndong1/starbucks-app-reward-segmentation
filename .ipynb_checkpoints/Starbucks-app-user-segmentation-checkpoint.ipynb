# %% [markdown]
# ### import pacakges

# %%
import numpy as np
import pandas as pd
from datetime import datetime

# %% [markdown]
# ### import dataset

# %%
portfolio = pd.read_json('portfolio.json', lines=True)
profile = pd.read_json('profile.json', lines=True)
transcript = pd.read_json('transcript.json', lines=True)

# %%
portfolio.to_csv('portfolio.csv')

# %%
profile
# Out:
#       gender  age                                id  became_member_on  \
# 0       None  118  68be06ca386d4c31939f3a4f0e3dd783          20170212
# 1          F   55  0610b486422d4921ae7d2bf64640c50b          20170715
# 2       None  118  38fe809add3b4fcf9315a9694bb96ff5          20180712
# 3          F   75  78afa995795e4d85b5d9ceeca43f5fef          20170509
# 4       None  118  a03223e636434f42ac4c3df47e8bac43          20170804
# ...      ...  ...                               ...               ...
# 16995      F   45  6d5f3a774f3d4714ab0c092238f3a1d7          20180604
# 16996      M   61  2cb4f97358b841b9a9773a7aa05a9d77          20180713
# 16997      M   49  01d26f638c274aa0b965d24cefe3183f          20170126
# 16998      F   83  9dc1421481194dcd9400aec7c9ae6366          20160307
# 16999      F   62  e4052622e5ba45a8b96b59aba68cf068          20170722
#
#          income
# 0           NaN
# 1      112000.0
# 2           NaN
# 3      100000.0
# 4           NaN
# ...         ...
# 16995   54000.0
# 16996   72000.0
# 16997   73000.0
# 16998   50000.0
# 16999   82000.0
#
# [17000 rows x 5 columns]

# %%
transcript
# Out:
#                                   person           event  \
# 0       78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1       a03223e636434f42ac4c3df47e8bac43  offer received
# 2       e2127556f4f64592b11af22de27a7932  offer received
# 3       8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4       68617ca6246f4fbc85e91a2a49552598  offer received
# ...                                  ...             ...
# 306529  b3a1272bc9904337b331bf348c3e8c17     transaction
# 306530  68213b08d99a4ae1b0dcb72aebd9aa35     transaction
# 306531  a00058cf10334a308c68e7631c529907     transaction
# 306532  76ddbd6576844afe811f1a3c0fbb5bec     transaction
# 306533  c02b10e8752c4d8e9b73f918558531f7     transaction
#
#                                                    value  time
# 0       {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}     0
# 1       {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}     0
# 2       {'offer id': '2906b810c7d4411798c6938adc9daaa5'}     0
# 3       {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}     0
# 4       {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}     0
# ...                                                  ...   ...
# 306529                    {'amount': 1.5899999999999999}   714
# 306530                                  {'amount': 9.53}   714
# 306531                                  {'amount': 3.61}   714
# 306532                    {'amount': 3.5300000000000002}   714
# 306533                                  {'amount': 4.05}   714
#
# [306534 rows x 4 columns]

# %% [markdown]
# ### summary statistics

# %% [markdown]
# Age is preprocessed, we ignore the variable.

# %%
profile['age'].describe()
# Out:
# count    17000.000000
# mean        62.531412
# std         26.738580
# min         18.000000
# 25%         45.000000
# 50%         58.000000
# 75%         73.000000
# max        118.000000
# Name: age, dtype: float64

# %% [markdown]
# Use the earliest date in became_numer_on to calculate duration of membership.

# %%
profile['became_member_on'] = profile['became_member_on'].apply(lambda x: datetime.strptime(str(x), '%Y%m%d'))

# %%
profile['duration'] = profile['became_member_on'].max() - profile['became_member_on']

# %%
profile['duration'] = profile['duration'].apply(lambda x: x.days)

# %%
profile
# Out:
#                                      id gender    income  duration
# 0      0610b486422d4921ae7d2bf64640c50b      F  112000.0       376
# 1      78afa995795e4d85b5d9ceeca43f5fef      F  100000.0       443
# 2      e2127556f4f64592b11af22de27a7932      M   70000.0        91
# 3      389bc3fa690240e798340f5a15918d5c      M   53000.0       167
# 4      2eeac8d8feae4a8cad5a6af0499a211d      M   51000.0       257
# ...                                 ...    ...       ...       ...
# 14820  6d5f3a774f3d4714ab0c092238f3a1d7      F   54000.0        52
# 14821  2cb4f97358b841b9a9773a7aa05a9d77      M   72000.0        13
# 14822  01d26f638c274aa0b965d24cefe3183f      M   73000.0       546
# 14823  9dc1421481194dcd9400aec7c9ae6366      F   50000.0       871
# 14824  e4052622e5ba45a8b96b59aba68cf068      F   82000.0       369
#
# [14825 rows x 4 columns]

# %% [markdown]
# drop all unknown gender and NaN income values

# %%
(17000-14825)/17000
# Out:
# 0.12794117647058822

# %%
profile = profile.dropna().reset_index(drop=True)

# %%
profile = profile[['id', 'gender', 'income', 'duration']]

# %% [markdown]
# transcript

# %%
transcript_summary = transcript.groupby(['person','event']).count().reset_index()

# %%
transcript_summary
# Out:
#                                  person            event  value  time
# 0      0009655768c64bdeb2e877511632db8f  offer completed      3     3
# 1      0009655768c64bdeb2e877511632db8f   offer received      5     5
# 2      0009655768c64bdeb2e877511632db8f     offer viewed      4     4
# 3      0009655768c64bdeb2e877511632db8f      transaction      8     8
# 4      00116118485d4dfda04fdbaba9a87b5c   offer received      2     2
# ...                                 ...              ...    ...   ...
# 63175  fffad4f4828548d1b5583907f2e9906b      transaction     12    12
# 63176  ffff82501cea40309d5fdd7edcca4a07  offer completed      6     6
# 63177  ffff82501cea40309d5fdd7edcca4a07   offer received      6     6
# 63178  ffff82501cea40309d5fdd7edcca4a07     offer viewed      6     6
# 63179  ffff82501cea40309d5fdd7edcca4a07      transaction     15    15
#
# [63180 rows x 4 columns]

# %%
transcript_pivot = transcript_summary.pivot(index='person', columns='event', values='value').reset_index().fillna(0)

# %%
transcript_pivot
# Out:
# event                            person  offer completed  offer received  \
# 0      0009655768c64bdeb2e877511632db8f              3.0             5.0
# 1      00116118485d4dfda04fdbaba9a87b5c              0.0             2.0
# 2      0011e0d4e6b944f998e987f904e8c1e5              3.0             5.0
# 3      0020c2b971eb4e9188eac86d93036a77              3.0             5.0
# 4      0020ccbbb6d84e358d3414a3ff76cffd              3.0             4.0
# ...                                 ...              ...             ...
# 16995  fff3ba4757bd42088c044ca26d73817a              3.0             6.0
# 16996  fff7576017104bcc8677a8d63322b5e1              3.0             5.0
# 16997  fff8957ea8b240a6b5e634b6ee8eafcf              0.0             3.0
# 16998  fffad4f4828548d1b5583907f2e9906b              3.0             4.0
# 16999  ffff82501cea40309d5fdd7edcca4a07              6.0             6.0
#
# event  offer viewed  transaction
# 0               4.0          8.0
# 1               2.0          3.0
# 2               5.0          5.0
# 3               3.0          8.0
# 4               4.0         12.0
# ...             ...          ...
# 16995           3.0         11.0
# 16996           4.0          6.0
# 16997           2.0          5.0
# 16998           4.0         12.0
# 16999           6.0         15.0
#
# [17000 rows x 5 columns]

# %% [markdown]
# construct outcome variables

# %%
transcript['value'] = transcript['value'].apply(lambda x: list(x.values())[0])

# %%
transcript
# Out:
#                                   person           event  \
# 0       78afa995795e4d85b5d9ceeca43f5fef  offer received
# 1       a03223e636434f42ac4c3df47e8bac43  offer received
# 2       e2127556f4f64592b11af22de27a7932  offer received
# 3       8ec6ce2a7e7949b1bf142def7d0e0586  offer received
# 4       68617ca6246f4fbc85e91a2a49552598  offer received
# ...                                  ...             ...
# 306529  b3a1272bc9904337b331bf348c3e8c17     transaction
# 306530  68213b08d99a4ae1b0dcb72aebd9aa35     transaction
# 306531  a00058cf10334a308c68e7631c529907     transaction
# 306532  76ddbd6576844afe811f1a3c0fbb5bec     transaction
# 306533  c02b10e8752c4d8e9b73f918558531f7     transaction
#
#                                    value  time
# 0       9b98b8c7a33c4b65b9aebfe6a799e6d9     0
# 1       0b1e1539f2cc45b7b9fa7c272da2e1d7     0
# 2       2906b810c7d4411798c6938adc9daaa5     0
# 3       fafdcd668e3743c1bb461111dcafc2a4     0
# 4       4d5c57ea9a6940dd891ad53e9dbe8da0     0
# ...                                  ...   ...
# 306529                              1.59   714
# 306530                              9.53   714
# 306531                              3.61   714
# 306532                              3.53   714
# 306533                              4.05   714
#
# [306534 rows x 4 columns]

# %% [markdown]
# Get all transaction amount for each user

# %%
transcript_transaction = transcript[transcript['event']=='transaction'].groupby(['person'])['value'].sum().reset_index()

# %%
transcript_transaction
# Out:
#                                  person   value
# 0      0009655768c64bdeb2e877511632db8f  127.60
# 1      00116118485d4dfda04fdbaba9a87b5c    4.09
# 2      0011e0d4e6b944f998e987f904e8c1e5   79.46
# 3      0020c2b971eb4e9188eac86d93036a77  196.86
# 4      0020ccbbb6d84e358d3414a3ff76cffd  154.05
# ...                                 ...     ...
# 16573  fff3ba4757bd42088c044ca26d73817a  580.98
# 16574  fff7576017104bcc8677a8d63322b5e1   29.94
# 16575  fff8957ea8b240a6b5e634b6ee8eafcf   12.15
# 16576  fffad4f4828548d1b5583907f2e9906b   88.83
# 16577  ffff82501cea40309d5fdd7edcca4a07  226.07
#
# [16578 rows x 2 columns]

# %%
transcript_input = pd.merge(transcript_pivot, transcript_transaction, how='left', on='person').fillna(0)

# %%
transcript_input
# Out:
#                                  person  offer completed  offer received  \
# 0      0009655768c64bdeb2e877511632db8f              3.0             5.0
# 1      00116118485d4dfda04fdbaba9a87b5c              0.0             2.0
# 2      0011e0d4e6b944f998e987f904e8c1e5              3.0             5.0
# 3      0020c2b971eb4e9188eac86d93036a77              3.0             5.0
# 4      0020ccbbb6d84e358d3414a3ff76cffd              3.0             4.0
# ...                                 ...              ...             ...
# 16995  fff3ba4757bd42088c044ca26d73817a              3.0             6.0
# 16996  fff7576017104bcc8677a8d63322b5e1              3.0             5.0
# 16997  fff8957ea8b240a6b5e634b6ee8eafcf              0.0             3.0
# 16998  fffad4f4828548d1b5583907f2e9906b              3.0             4.0
# 16999  ffff82501cea40309d5fdd7edcca4a07              6.0             6.0
#
#        offer viewed  transaction   value
# 0               4.0          8.0  127.60
# 1               2.0          3.0    4.09
# 2               5.0          5.0   79.46
# 3               3.0          8.0  196.86
# 4               4.0         12.0  154.05
# ...             ...          ...     ...
# 16995           3.0         11.0  580.98
# 16996           4.0          6.0   29.94
# 16997           2.0          5.0   12.15
# 16998           4.0         12.0   88.83
# 16999           6.0         15.0  226.07
#
# [17000 rows x 6 columns]

# %% [markdown]
# get transaction amount for each promotion event for each user

# %%
transcript_offer = transcript[transcript['event'] != 'transaction'].reset_index()

# %%
transcript_offer = transcript_offer.groupby(by=['person','event','value']).count().reset_index()

# %%
transcript_offer_completion = pd.merge(transcript_offer[transcript_offer['event']=='offer received'],
                                       transcript_offer[transcript_offer['event']=='offer completed'],
                                       how='left',
                                       on = ['person','value'])

# %%
transcript_offer_completion = transcript_offer_completion.fillna(0)

# %%
transcript_offer_completion
# Out:
#                                  person         event_x  \
# 0      0009655768c64bdeb2e877511632db8f  offer received
# 1      0009655768c64bdeb2e877511632db8f  offer received
# 2      0009655768c64bdeb2e877511632db8f  offer received
# 3      0009655768c64bdeb2e877511632db8f  offer received
# 4      0009655768c64bdeb2e877511632db8f  offer received
# ...                                 ...             ...
# 63283  fffad4f4828548d1b5583907f2e9906b  offer received
# 63284  ffff82501cea40309d5fdd7edcca4a07  offer received
# 63285  ffff82501cea40309d5fdd7edcca4a07  offer received
# 63286  ffff82501cea40309d5fdd7edcca4a07  offer received
# 63287  ffff82501cea40309d5fdd7edcca4a07  offer received
#
#                                   value  index_x  time_x          event_y  \
# 0      2906b810c7d4411798c6938adc9daaa5        1       1  offer completed
# 1      3f207df678b143eea3cee63160fa8bed        1       1                0
# 2      5a8bc65990b245e5a138643cd4eb9837        1       1                0
# 3      f19421c1d4aa40978ebb69ca19b0e20d        1       1  offer completed
# 4      fafdcd668e3743c1bb461111dcafc2a4        1       1  offer completed
# ...                                 ...      ...     ...              ...
# 63283  f19421c1d4aa40978ebb69ca19b0e20d        2       2  offer completed
# 63284  0b1e1539f2cc45b7b9fa7c272da2e1d7        1       1  offer completed
# 63285  2906b810c7d4411798c6938adc9daaa5        3       3  offer completed
# 63286  9b98b8c7a33c4b65b9aebfe6a799e6d9        1       1  offer completed
# 63287  fafdcd668e3743c1bb461111dcafc2a4        1       1  offer completed
#
#        index_y  time_y
# 0          1.0     1.0
# 1          0.0     0.0
# 2          0.0     0.0
# 3          1.0     1.0
# 4          1.0     1.0
# ...        ...     ...
# 63283      2.0     2.0
# 63284      1.0     1.0
# 63285      3.0     3.0
# 63286      1.0     1.0
# 63287      1.0     1.0
#
# [63288 rows x 8 columns]

# %%
transcript_offer_completion['completion rate'] = transcript_offer_completion['index_y']/transcript_offer_completion['index_x']

# %%
transcript_offer_completion = transcript_offer_completion[['person', 'value', 'completion rate']]

# %%
transcript_offer_completion = transcript_offer_completion.pivot(index='person', columns='value', values='completion rate').reset_index()

# %%
transcript_offer_completion
# Out:
# value                            person  0b1e1539f2cc45b7b9fa7c272da2e1d7  \
# 0      0009655768c64bdeb2e877511632db8f                               NaN
# 1      00116118485d4dfda04fdbaba9a87b5c                               NaN
# 2      0011e0d4e6b944f998e987f904e8c1e5                               1.0
# 3      0020c2b971eb4e9188eac86d93036a77                               NaN
# 4      0020ccbbb6d84e358d3414a3ff76cffd                               NaN
# ...                                 ...                               ...
# 16989  fff3ba4757bd42088c044ca26d73817a                               NaN
# 16990  fff7576017104bcc8677a8d63322b5e1                               NaN
# 16991  fff8957ea8b240a6b5e634b6ee8eafcf                               NaN
# 16992  fffad4f4828548d1b5583907f2e9906b                               NaN
# 16993  ffff82501cea40309d5fdd7edcca4a07                               1.0
#
# value  2298d6c36e964ae4a3e7e9706d1fb8c2  2906b810c7d4411798c6938adc9daaa5  \
# 0                                   NaN                               1.0
# 1                                   NaN                               NaN
# 2                                   1.0                               NaN
# 3                                   NaN                               NaN
# 4                                   1.0                               NaN
# ...                                 ...                               ...
# 16989                               NaN                               0.5
# 16990                               NaN                               NaN
# 16991                               NaN                               NaN
# 16992                               NaN                               NaN
# 16993                               NaN                               1.0
#
# value  3f207df678b143eea3cee63160fa8bed  4d5c57ea9a6940dd891ad53e9dbe8da0  \
# 0                                   0.0                               NaN
# 1                                   NaN                               NaN
# 2                                   0.0                               NaN
# 3                                   NaN                               1.0
# 4                                   NaN                               NaN
# ...                                 ...                               ...
# 16989                               NaN                               NaN
# 16990                               NaN                               0.0
# 16991                               0.0                               0.0
# 16992                               NaN                               NaN
# 16993                               NaN                               NaN
#
# value  5a8bc65990b245e5a138643cd4eb9837  9b98b8c7a33c4b65b9aebfe6a799e6d9  \
# 0                                   0.0                               NaN
# 1                                   NaN                               NaN
# 2                                   0.0                               1.0
# 3                                   0.0                               NaN
# 4                                   0.0                               1.0
# ...                                 ...                               ...
# 16989                               0.0                               1.0
# 16990                               NaN                               1.0
# 16991                               NaN                               NaN
# 16992                               0.0                               1.0
# 16993                               NaN                               1.0
#
# value  ae264e3637204a6fb9bb56bc8210ddfd  f19421c1d4aa40978ebb69ca19b0e20d  \
# 0                                   NaN                               1.0
# 1                                   NaN                               0.0
# 2                                   NaN                               NaN
# 3                                   0.0                               NaN
# 4                                   NaN                               1.0
# ...                                 ...                               ...
# 16989                               NaN                               NaN
# 16990                               0.0                               NaN
# 16991                               NaN                               NaN
# 16992                               NaN                               1.0
# 16993                               NaN                               NaN
#
# value  fafdcd668e3743c1bb461111dcafc2a4
# 0                                   1.0
# 1                                   NaN
# 2                                   NaN
# 3                                   1.0
# 4                                   NaN
# ...                                 ...
# 16989                               1.0
# 16990                               1.0
# 16991                               0.0
# 16992                               NaN
# 16993                               1.0
#
# [16994 rows x 11 columns]

# %% [markdown]
# ### Construct input and outcome dataframes

# %%
df_input = pd.merge(profile, transcript_input, how='left', left_on='id', right_on='person').drop(columns='person')
df_input['gender'] = df_input['gender'].apply(lambda x: 1 if x == 'F' else 0)

# %%
X = df_input[['gender', 'income', 'duration', 'offer received', 'offer viewed', 'offer completed', 'transaction', 'value']]

# %%
X
# Out:
#        gender    income  duration  offer received  offer viewed  \
# 0           1  112000.0       376             2.0           0.0
# 1           1  100000.0       443             4.0           4.0
# 2           0   70000.0        91             4.0           3.0
# 3           0   53000.0       167             6.0           6.0
# 4           0   51000.0       257             3.0           2.0
# ...       ...       ...       ...             ...           ...
# 14820       1   54000.0        52             3.0           3.0
# 14821       0   72000.0        13             3.0           1.0
# 14822       0   73000.0       546             3.0           1.0
# 14823       1   50000.0       871             3.0           3.0
# 14824       1   82000.0       369             4.0           2.0
#
#        offer completed  transaction   value
# 0                  1.0          3.0   77.01
# 1                  3.0          7.0  159.27
# 2                  2.0          3.0   57.73
# 3                  5.0          3.0   36.43
# 4                  1.0          4.0   15.62
# ...                ...          ...     ...
# 14820              0.0          7.0   20.03
# 14821              1.0          7.0   25.97
# 14822              0.0          8.0   39.74
# 14823              3.0         14.0  189.67
# 14824              2.0          6.0  143.02
#
# [14825 rows x 8 columns]

# %% [markdown]
# Transform the data to the same scale

# %%
from sklearn.preprocessing import StandardScaler
stdsc = StandardScaler()
X_std = stdsc.fit_transform(X)

# %%
from sklearn.cluster import KMeans

# %%
kmeans_kwargs = {
    "init": "random",
    "n_init": 10,
    "max_iter": 300,
    "random_state": 42}


# A list holds the SSE values for each k
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(X_std)
    sse.append(kmeans.inertia_)

# %%
import matplotlib.pyplot as plt
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kmeans = KMeans(n_clusters=4, random_state=0).fit(X_std)

# %%
kmeans.labels_
# Out:
# array([3, 3, 1, ..., 3, 0, 3], dtype=int32)

# %%
X['label'] = kmeans.labels_
# Out:
# /Users/apple/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
cluster = X.groupby('label').mean()

# %%
cluster.to_csv('cluster.csv')

# %%
df_input['label'] = kmeans.labels_

# %%
df = df_input[['id', 'label']]

# %%
output_df = pd.merge(df, transcript_offer_completion, how='left', left_on='id', right_on='person').drop(columns=['id', 'person'])

# %%
outcome = output_df.groupby('label').mean()

# %%
outcome.to_csv('outcome.csv')
